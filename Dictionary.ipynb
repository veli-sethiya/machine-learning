# %% [markdown]
# <a href="https://colab.research.google.com/github/veli-sethiya/machine-learning/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
birthday={"jan":0,"feb":0,"mar":0,"apr":0,"may":1,"june":0,"july":0,"aug":0,"sep":0,"oct":0,"nov":0,"dec":0}
while(True):
  mon=input()
  if mon =="":
    break
  else:
    birthday[mon]=birthday[mon]+1

minv=birthday["jan"]
for i in birthday.keys():
  if birthday[i]<minv:
    minv=birthday[i]

maxv=birthday["jan"]
for i in birthday.keys():
  if birthday[i]>maxv:
    maxv=birthday[i]

print(birthday)
print(f"Minimum no of birthday in a month are {minv} ")
print(f"Maximum no of birthday in a month are {maxv} ")
