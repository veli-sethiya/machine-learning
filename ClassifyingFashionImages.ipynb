# %% [markdown]
# <a href="https://colab.research.google.com/github/veli-sethiya/machine-learning/blob/main/ClassifyingFashionImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0.beta1
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.0.0.beta1 (from versions: 1.13.1, 1.13.2, 1.14.0, 1.15.0, 1.15.2, 1.15.3, 1.15.4, 1.15.5, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.9.0rc0, 2.9.0rc1)
# ERROR: No matching distribution found for tensorflow==2.0.0.beta1

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
fasion_minst=keras.datasets.fashion_mnist
(train_images, train_label),(test_images,test_labels)=fasion_minst.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
classname=["T_shirt/top","Trouser","Pullover","Dress","Coat", "Sandal","Shirt","Sneaker","bag","Ankle boot"]
print(train_images.shape)
len(train_label)
# Out:
# (60000, 28, 28)
# 60000

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images=train_images/255
test_images=test_images/255

# %%
train_label
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks(())
  plt.yticks(())
  plt.imshow(train_images[i],cmap=plt.cm.binary)
  plt.xlabel(classname[train_label[i]])
  plt.show()

# %%
model=keras.Sequential([keras.layers.Flatten(input_shape=(28,28)),keras.layers.Dense(28, activation='relu'),keras.layers.Dense(10, activation='softmax')])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_images,train_label,epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5420 - accuracy: 0.8131
# Epoch 2/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4055 - accuracy: 0.8569
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3742 - accuracy: 0.8680
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3535 - accuracy: 0.8726
# Epoch 5/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3415 - accuracy: 0.8770
# Epoch 6/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3283 - accuracy: 0.8817
# Epoch 7/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3208 - accuracy: 0.8824
# Epoch 8/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3110 - accuracy: 0.8868
# Epoch 9/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3033 - accuracy: 0.8898
# Epoch 10/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2994 - accuracy: 0.8910
# Epoch 11/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2951 - accuracy: 0.8931
# Epoch 12/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2889 - accuracy: 0.8941
# Epoch 13/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2838 - accuracy: 0.8965
# Epoch 14/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2806 - accuracy: 0.8981
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2766 - accuracy: 0.8992
# Epoch 16/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2704 - accuracy: 0.9014
# Epoch 17/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2688 - accuracy: 0.9024
# Epoch 18/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2661 - accuracy: 0.9028
# Epoch 19/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2625 - accuracy: 0.9034
# Epoch 20/20
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2598 - accuracy: 0.9053

# %%
test_loos,test_acc=model.evaluate(test_images,test_labels)
print(test_acc)
# Out:
# 313/313 [==============================] - 0s 981us/step - loss: 0.3918 - accuracy: 0.8614
# 0.8614000082015991

# %%
prediciton=model.predict(test_images)

# %%
prediciton[0]
print(np.argmax(prediciton[0]))
print(test_labels[0])
# Out:
# 9
# 9
